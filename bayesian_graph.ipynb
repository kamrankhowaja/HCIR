# %%
# !pip install pyAgrum
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyAgrum in /home/ksk/.local/lib/python3.10/site-packages (2.3.2)
# Requirement already satisfied: pydot in /usr/lib/python3/dist-packages (from pyAgrum) (1.4.2)
# Requirement already satisfied: numpy in /home/ksk/.local/lib/python3.10/site-packages (from pyAgrum) (2.2.6)
# Requirement already satisfied: scikit-learn>=1.7 in /home/ksk/.local/lib/python3.10/site-packages (from pyAgrum) (1.7.2)
# Requirement already satisfied: matplotlib in /home/ksk/.local/lib/python3.10/site-packages (from pyAgrum) (3.10.8)
# Requirement already satisfied: scipy>=1.8.0 in /usr/lib/python3/dist-packages (from scikit-learn>=1.7->pyAgrum) (1.8.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ksk/.local/lib/python3.10/site-packages (from scikit-learn>=1.7->pyAgrum) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ksk/.local/lib/python3.10/site-packages (from scikit-learn>=1.7->pyAgrum) (1.5.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (1.4.9)
# Requirement already satisfied: cycler>=0.10 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (0.12.1)
# Requirement already satisfied: pyparsing>=3 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (3.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (26.0)
# Requirement already satisfied: pillow>=8 in /home/ksk/.local/lib/python3.10/site-packages (from matplotlib->pyAgrum) (12.1.1)
# Requirement already satisfied: six>=1.5 in /home/ksk/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pyAgrum) (1.17.0)

# %%
import pyagrum as gum
import pyagrum.lib.notebook as gnb

# Create Bayesian Network for social event recommendation
bn = gum.fastBN(
    "recognized_user{known|unknown}"
    "->user_preference_history{music|food|sports|culture|networking|games|none};"

    "user_preference_history"
    "->event_match_score{low|medium|high};"

    "mood{relaxed|excited|stressed}"
    "->event_match_score;"

    "social_energy{low|medium|high}"
    "->event_match_score;"

    "budget_preference{free|low|medium|high}"
    "->event_match_score;"

    "time_availability{short|medium|long}"
    "->event_match_score;"

    "indoor_outdoor_preference{indoor|outdoor|no_preference}"
    "->event_match_score;"

    "group_size{alone|pair|small_group|large_group}"
    "->event_match_score;"

    "interest_type{music|food|sports|culture|networking|games}"
    "->event_match_score;"

    "event_match_score"
    "->recommended_event{concert|food_festival|sports_event|museum_night|student_meetup|board_game_night|picnic}"
)


gnb.showBN(bn)
# Out:
# /home/ksk/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
